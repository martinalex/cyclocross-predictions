# %%
import pandas as pd
import numpy as np
from pathlib import Path
import joblib
import json

DATA_DIR = Path("data")
CLEAN_DIR = DATA_DIR / "clean"
MODELS_DIR = Path("models")

startlists_path = CLEAN_DIR / "startlists_enriched.csv"
model_path = MODELS_DIR / "baseline_rank_model.joblib"
meta_path = MODELS_DIR / "feature_meta.json"

print("Loading:\n -", startlists_path, "\n -", model_path, "\n -", meta_path)

startlists = pd.read_csv(startlists_path, parse_dates=["race_date"])
model = joblib.load(model_path)

with open(meta_path, "r") as f:
    meta = json.load(f)
feature_cols = meta["feature_cols"]

startlists.head()
# Out:
# Loading:
#  - data/clean/startlists_enriched.csv
#  - models/baseline_rank_model.joblib
#  - models/feature_meta.json
#     Nr                    Naam        UCI ID  Nat  \
# 0  1.0              AERTS Toon  1.000759e+10  BEL
# 1  2.0              NYS Thibau  1.006500e+10  BEL
# 2  3.0  VANTHOURENHOUT Michael  1.000716e+10  BEL
# 3  4.0        VANDEPUTTE Niels  1.001633e+10  BEL
# 4  5.0           WYSEURE Joran  1.006492e+10  BEL
#
#                                       Club  UCI Rank  series_name  \
# 0                   DESCHACHT-HENS CX TEAM       2.0          NaN
# 1                      BALOISE GLOWI LIONS       9.0          NaN
# 2  PAUWELS SAUZEN - ALTEZ INDUSTRIEBOUW CT       1.0          NaN
# 3      ALPECIN-DECEUNINCK DEVELOPMENT TEAM       4.0          NaN
# 4                          CRELAN-CORENDON       5.0          NaN
#
#                                            race_name race_date  race_location  \
# 0  Telenet Superprestige AARDBEIENCROSS-MERKSPLAS...       NaT            NaN
# 1  Telenet Superprestige AARDBEIENCROSS-MERKSPLAS...       NaT            NaN
# 2  Telenet Superprestige AARDBEIENCROSS-MERKSPLAS...       NaT            NaN
# 3  Telenet Superprestige AARDBEIENCROSS-MERKSPLAS...       NaT            NaN
# 4  Telenet Superprestige AARDBEIENCROSS-MERKSPLAS...       NaT            NaN
#
#    ...      merge_id race_id_y races_so_far avg_place_last3  best_place_last5  \
# 0  ...  1.000759e+10       NaN          NaN             NaN               NaN
# 1  ...  1.006500e+10       NaN          NaN             NaN               NaN
# 2  ...  1.000716e+10       NaN          NaN             NaN               NaN
# 3  ...  1.001633e+10       NaN          NaN             NaN               NaN
# 4  ...  1.006492e+10       NaN          NaN             NaN               NaN
#
#    last_place  days_since_last_race  last_carried_points  last_scored_points  \
# 0         NaN                   NaN                  NaN                 NaN
# 1         NaN                   NaN                  NaN                 NaN
# 2         NaN                   NaN                  NaN                 NaN
# 3         NaN                   NaN                  NaN                 NaN
# 4         NaN                   NaN                  NaN                 NaN
#
#    Place
# 0    NaN
# 1    NaN
# 2    NaN
# 3    NaN
# 4    NaN
#
# [5 rows x 24 columns]

# %%
def clean_startlist(df):
    df = df.copy()

    # Remove header rows (common in PDF extraction)
    header_mask = df.get("rider_name", pd.Series(index=df.index, dtype=bool)).fillna("").str.contains(
        "UCI ID", case=False, na=False
    )
    df = df[~header_mask]

    # Ensure category_full exists
    if "category_full" not in df.columns:
        df["category_full"] = np.nan

    # Fix NaN in category_full by falling back to category_hint (if present)
    if "category_hint" in df.columns:
        df["category_full"] = df["category_full"].fillna(df["category_hint"])

    # Last fallback: default to "Unknown" for anything still missing
    df["category_full"] = df["category_full"].fillna("Unknown")

    # Normalize category capitalization
    df["category_full"] = (
        df["category_full"]
        .astype(str)
        .str.strip()
        .str.replace(r"\s+", " ", regex=True)
    )

    # Optionally map to a canonical set
    mapping = {
        "men elite": "Men Elite",
        "women elite": "Women Elite",
        "men u23": "Men U23",
        "u23": "Men U23",
        "men junior": "Men Junior",
        "junior": "Men Junior",
    }
    df["category_full"] = df["category_full"].str.lower().map(mapping).fillna(df["category_full"])

    return df

startlists = clean_startlist(startlists)
startlists.head()
# Out:
#     Nr                    Naam        UCI ID  Nat  \
# 0  1.0              AERTS Toon  1.000759e+10  BEL
# 1  2.0              NYS Thibau  1.006500e+10  BEL
# 2  3.0  VANTHOURENHOUT Michael  1.000716e+10  BEL
# 3  4.0        VANDEPUTTE Niels  1.001633e+10  BEL
# 4  5.0           WYSEURE Joran  1.006492e+10  BEL
#
#                                       Club  UCI Rank  series_name  \
# 0                   DESCHACHT-HENS CX TEAM       2.0          NaN
# 1                      BALOISE GLOWI LIONS       9.0          NaN
# 2  PAUWELS SAUZEN - ALTEZ INDUSTRIEBOUW CT       1.0          NaN
# 3      ALPECIN-DECEUNINCK DEVELOPMENT TEAM       4.0          NaN
# 4                          CRELAN-CORENDON       5.0          NaN
#
#                                            race_name race_date  race_location  \
# 0  Telenet Superprestige AARDBEIENCROSS-MERKSPLAS...       NaT            NaN
# 1  Telenet Superprestige AARDBEIENCROSS-MERKSPLAS...       NaT            NaN
# 2  Telenet Superprestige AARDBEIENCROSS-MERKSPLAS...       NaT            NaN
# 3  Telenet Superprestige AARDBEIENCROSS-MERKSPLAS...       NaT            NaN
# 4  Telenet Superprestige AARDBEIENCROSS-MERKSPLAS...       NaT            NaN
#
#    ...      merge_id race_id_y races_so_far avg_place_last3  best_place_last5  \
# 0  ...  1.000759e+10       NaN          NaN             NaN               NaN
# 1  ...  1.006500e+10       NaN          NaN             NaN               NaN
# 2  ...  1.000716e+10       NaN          NaN             NaN               NaN
# 3  ...  1.001633e+10       NaN          NaN             NaN               NaN
# 4  ...  1.006492e+10       NaN          NaN             NaN               NaN
#
#    last_place  days_since_last_race  last_carried_points  last_scored_points  \
# 0         NaN                   NaN                  NaN                 NaN
# 1         NaN                   NaN                  NaN                 NaN
# 2         NaN                   NaN                  NaN                 NaN
# 3         NaN                   NaN                  NaN                 NaN
# 4         NaN                   NaN                  NaN                 NaN
#
#    Place
# 0    NaN
# 1    NaN
# 2    NaN
# 3    NaN
# 4    NaN
#
# [5 rows x 24 columns]

# %%
# Prepare features safely
X = startlists[feature_cols].copy()

# Find a safe default median place (if your historical results had Places)
# If everything is NaN → fallback to 25
safe_place_default = (
    startlists["Place"].median()
    if ("Place" in startlists.columns and startlists["Place"].notna().any())
    else 25
)

X = X.fillna({
    "races_so_far": 0,
    "avg_place_last3": safe_place_default,
    "best_place_last5": safe_place_default,
    "last_place": safe_place_default,
    "days_since_last_race": 30,
    "last_carried_points": 0,
    "last_scored_points": 0,
})

# %%
# --- FIX: Ensure race_id exists and is clean ---

# If race_id exists, keep it.
if "race_id" in startlists.columns:
    pass

# If merge created race_id_x / race_id_y, fix it.
elif "race_id_x" in startlists.columns:
    startlists["race_id"] = startlists["race_id_x"]

elif "race_id_y" in startlists.columns:
    startlists["race_id"] = startlists["race_id_y"]

# Last resort: if nothing exists, build a placeholder
else:
    startlists["race_id"] = "unknown_race"

# Clean type and missing values
startlists["race_id"] = startlists["race_id"].fillna("unknown_race").astype(str)

print("Race ID distribution:")
print(startlists["race_id"].value_counts().head())
# Out:
# Race ID distribution:
# race_id
# unknown_standalone_x2o-badkamers-trofee-rectavit-flandriencross-hamme-16-11-2025_noloc    189
# unknown_standalone_telenet-superprestige-aardbeiencross-merksplas-15-11-2025_noloc         81
# Name: count, dtype: int64

# %%
y_rank_pred = model.predict(X)

# Prevent division by zero
y_rank_pred = np.clip(y_rank_pred, 1e-6, None)

startlists["predicted_place"] = 1.0 / y_rank_pred

# Predicted rank = sorted order
startlists["predicted_rank"] = (
    startlists.groupby(["race_id", "category_full"])["predicted_place"]
              .rank(method="first")
)

# %%
for (rid, cat), grp in startlists.groupby(["race_id", "category_full"]):

    print("\n==============================")
    print(f"RACE: {rid}")
    print(f"CATEGORY: {cat}")
    print("==============================\n")

    # dynamic columns
    cols = ["rider_name", "predicted_place", "predicted_rank"]
    if "UCI Rank" in grp.columns:
        cols.insert(1, "UCI Rank")
    if "UCI ID" in grp.columns:
        cols.insert(1, "UCI ID")

    display(
        grp[cols]
        .sort_values("predicted_rank")
        .reset_index(drop=True)
        .head(25)
    )
# Out:
# ==============================
# RACE: unknown_standalone_telenet-superprestige-aardbeiencross-merksplas-15-11-2025_noloc
# CATEGORY: Men Elite
# ==============================
#                 rider_name        UCI ID  UCI Rank  predicted_place  \
# 0               AERTS Toon  1.000759e+10       2.0        10.782739
# 1               NYS Thibau  1.006500e+10       9.0        10.782739
# 2   VANTHOURENHOUT Michael  1.000716e+10       1.0        10.782739
# 3         VANDEPUTTE Niels  1.001633e+10       4.0        10.782739
# 4            WYSEURE Joran  1.006492e+10       5.0        10.782739
# 5           SWEECK Laurens  1.000691e+10       7.0        10.782739
# 6        VAN DER HAAR Lars  1.000612e+10       8.0        10.782739
# 7              RONHAAR Pim  1.002311e+10      10.0        10.782739
# 8       ORTS LLORET Felipe  1.000900e+10      11.0        10.782739
# 9               KUHN Kevin  1.000975e+10      14.0        10.782739
# 10       NIEUWENHUIS Joris  1.000871e+10      15.0        10.782739
# 11           MASON Cameron  1.002357e+10      18.0        10.782739
# 12           MICHELS Jente  1.006501e+10      20.0        10.782739
# 13           HENDRIKX Mees  1.001652e+10      22.0        10.782739
# 14               KAMP Ryan  1.002336e+10      24.0        10.782739
# 15         VANDEBOSCH Toon  1.001094e+10      26.0        10.782739
# 16            CORSUS Yordi  1.006512e+10      34.0        10.782739
# 17        DE BRUYCKERE Kay  1.006505e+10      35.0        10.782739
# 18  SUAREZ FERNANDEZ Kevin  1.000758e+10      37.0        10.782739
# 19     VAN DE PUTTE Victor  1.006499e+10      40.0        10.782739
# 20          MEEUSSEN Witse  1.006493e+10      51.0        10.782739
# 21           HORNY Clement  1.001642e+10      59.0        10.782739
# 22        VAN LIEROP Danny  1.002332e+10      79.0        10.782739
# 23         MARASCO Lorenzo  1.002353e+10      97.0        10.782739
# 24          KUYPERS Gerben  1.001632e+10      98.0        10.782739
#
#     predicted_rank
# 0              1.0
# 1              2.0
# 2              3.0
# 3              4.0
# 4              5.0
# 5              6.0
# 6              7.0
# 7              8.0
# 8              9.0
# 9             10.0
# 10            11.0
# 11            12.0
# 12            13.0
# 13            14.0
# 14            15.0
# 15            16.0
# 16            17.0
# 17            18.0
# 18            19.0
# 19            20.0
# 20            21.0
# 21            22.0
# 22            23.0
# 23            24.0
# 24            25.0
# ==============================
# RACE: unknown_standalone_telenet-superprestige-aardbeiencross-merksplas-15-11-2025_noloc
# CATEGORY: Women Elite
# ==============================
#                rider_name        UCI ID  UCI Rank  predicted_place  \
# 0    VAN DER HEIJDEN Inge  1.001059e+10       3.0        10.782739
# 1           BRAND Lucinda  1.000661e+10       1.0        10.782739
# 2            BAKKER Manon  1.000952e+10       8.0        10.782739
# 3           CASASOLA Sara  1.001100e+10      11.0        10.782739
# 4         BENTVELD Leonie  1.002334e+10      12.0        10.782739
# 5          BROUWERS Julie  1.006501e+10      13.0        10.782739
# 6        VAN ALPHEN Aniek  1.001554e+10      14.0        10.782739
# 7          CLAUZEL Hélène  1.000988e+10      15.0        10.782739
# 8          BETSEMA Denise  1.000765e+10      16.0        10.782739
# 9      FOUQUENET Amandine  1.006677e+10      17.0        10.782739
# 10          PEETERS Jinse  1.001114e+10      38.0        10.782739
# 11               KAY Anna  1.001547e+10      39.0        10.782739
# 12         HARTOG Larissa  1.002271e+10      64.0        10.782739
# 13      MOLENGRAAF Lauren  1.002335e+10      70.0        10.782739
# 14        CLAUZEL Perrine  1.000770e+10      72.0        10.782739
# 15          DE BEER Jamie  1.015543e+10      86.0        10.782739
# 16        VERVLOET Sterre  1.006504e+10     105.0        10.782739
# 17  DE SCHOESITTER Shanyl  1.006515e+10     115.0        10.782739
# 18               MOES Noï  1.002319e+10     129.0        10.782739
# 19            MOORS Fleur  1.010340e+10     149.0        10.782739
# 20     HLADÍKOVÁ Kateřina  1.004777e+10     175.0        10.782739
# 21         SONNEMANS Sara  1.002319e+10     189.0        10.782739
# 22             WENZEL Liv  1.003500e+10     197.0        10.782739
# 23   DE RAEDEMAEKER Alexe  1.009908e+10     279.0        10.782739
# 24            BAELE Lotte  1.007524e+10     303.0        10.782739
#
#     predicted_rank
# 0              1.0
# 1              2.0
# 2              3.0
# 3              4.0
# 4              5.0
# 5              6.0
# 6              7.0
# 7              8.0
# 8              9.0
# 9             10.0
# 10            11.0
# 11            12.0
# 12            13.0
# 13            14.0
# 14            15.0
# 15            16.0
# 16            17.0
# 17            18.0
# 18            19.0
# 19            20.0
# 20            21.0
# 21            22.0
# 22            23.0
# 23            24.0
# 24            25.0
# ==============================
# RACE: unknown_standalone_x2o-badkamers-trofee-rectavit-flandriencross-hamme-16-11-2025_noloc
# CATEGORY: Unknown
# ==============================
#             rider_name        UCI ID  UCI Rank  predicted_place  \
# 0        SVOBODA David  1.004711e+10      13.0        10.782739
# 1        HEEREN Delano  1.004577e+10      18.0        10.782739
# 2        LIPPENS Brent  1.010605e+10      27.0        10.782739
# 3         VAN LEE Jari  1.006522e+10      28.0        10.782739
# 4          OSAER Emiel  1.007488e+10      36.0        10.782739
# 5         SMITS Maxime  1.010817e+10      58.0        10.782739
# 6         VAN HOOF Kai  1.005975e+10      61.0        10.782739
# 7       DE PEUTER Toon  1.006523e+10      62.0        10.782739
# 8      JANSSENS Arthur  1.006522e+10      69.0        10.782739
# 9      DECLERCQ Matteo  1.008507e+10      80.0        10.782739
# 10     SPRANGERS Seppe  1.011298e+10      84.0        10.782739
# 11       BEETGE Tanner  1.014757e+10     100.0        10.782739
# 12     ROIJACKERS Matt  1.009653e+10     109.0        10.782739
# 13          GEERTS Len  1.007792e+10     119.0        10.782739
# 14         MAENEN Dani  1.013843e+10     132.0        10.782739
# 15        RENDERS Luca  1.012589e+10     147.0        10.782739
# 16          ROELS Dima  1.010531e+10     188.0        10.782739
# 17    ROELANDT Alessio  1.008561e+10     190.0        10.782739
# 18        DE BOIS Nand  1.007362e+10     215.0        10.782739
# 19        DIJKMAN Sven  1.008765e+10     242.0        10.782739
# 20       VAN HOECK Sam  1.007789e+10     249.0        10.782739
# 21         GEENS Matiz  1.006525e+10     255.0        10.782739
# 22      DE LOOSE Senne  1.007175e+10     261.0        10.782739
# 23       VANHOUDT Kobe  1.006524e+10       NaN        10.782739
# 24  VAN RAEMDONCK Daan  1.007212e+10       NaN        10.782739
#
#     predicted_rank
# 0              1.0
# 1              2.0
# 2              3.0
# 3              4.0
# 4              5.0
# 5              6.0
# 6              7.0
# 7              8.0
# 8              9.0
# 9             10.0
# 10            11.0
# 11            12.0
# 12            13.0
# 13            14.0
# 14            15.0
# 15            16.0
# 16            17.0
# 17            18.0
# 18            19.0
# 19            20.0
# 20            21.0
# 21            22.0
# 22            23.0
# 23            24.0
# 24            25.0

# %%
output_dir = CLEAN_DIR / "predictions"
output_dir.mkdir(exist_ok=True)

saved_files = []

for (rid, cat), grp in startlists.groupby(["race_id", "category_full"]):
    safe_cat = cat.lower().replace(" ", "-")
    out_path = output_dir / f"{rid}_{safe_cat}.csv"

    grp.to_csv(out_path, index=False)
    saved_files.append(out_path)

saved_files
# Out:
# [PosixPath('data/clean/predictions/unknown_standalone_telenet-superprestige-aardbeiencross-merksplas-15-11-2025_noloc_men-elite.csv'),
#  PosixPath('data/clean/predictions/unknown_standalone_telenet-superprestige-aardbeiencross-merksplas-15-11-2025_noloc_women-elite.csv'),
#  PosixPath('data/clean/predictions/unknown_standalone_x2o-badkamers-trofee-rectavit-flandriencross-hamme-16-11-2025_noloc_unknown.csv')]

# %%
combined_path = CLEAN_DIR / "predicted_rankings_all.csv"
startlists.to_csv(combined_path, index=False)

combined_path
# Out:
# PosixPath('data/clean/predicted_rankings_all.csv')

# %%
import pdfplumber

x2o_path = "/Users/marlex/projects/cyclocross-predictions/data/startlists/X2O BADKAMERS TROFEE RECTAVIT-FLANDRIENCROSS-HAMME 16:11:2025 STARTLIST.pdf"

with pdfplumber.open(x2o_path) as pdf:
    text = pdf.pages[0].extract_text()
    print("\n".join(text.split("\n")[:140]))
# Out:
# FLANDRIENCROSS-HAMME 16/11/2025
# STARTLIST MEN JUNIOR
# Nr Naam UCI ID Nat Club UCI Rank
# 1 SVOBODA David 10047109850 CZE BRILON RACING TEAM MB 13
# 2 HEEREN Delano 10045767311 NED ACROG TORMANS 18
# 3 LIPPENS Brent 10106047656 BEL C.T. KEUKENS BUYSSE KNESSELARE VZW 27
# 4 VAN LEE Jari 10065219649 BEL BIOMETRIC - CANYON CT 28
# 5 OSAER Emiel 10074876708 BEL STARBIKES - VISTABUILD 36
# 6 SMITS Maxime 10108174380 BEL ACROG-TORMANS 58
# 7 VAN HOOF Kai 10059748041 NED TWC HET SNELLE WIEL 61
# 8 DE PEUTER Toon 10065230763 BEL UCT CYCLING TEAM 62
# 9 JANSSENS Arthur 10065223588 BEL GOLAZO YOUNG LIONS 69
# 10 DECLERCQ Matteo 10085069788 BEL WIELERCLUB "ONDER - ONS PARIKE" VZW 80
# 11 SPRANGERS Seppe 10112980631 BEL ACROG-TORMANS 84
# 12 BEETGE Tanner 10147572548 GBR DONOVAN RACING DEVELOPMENT 100
# 13 ROIJACKERS Matt 10096529532 NED ZZPR ORANGE BABIES CYCLING TEAM 109
# 14 GEERTS Len 10077916848 BEL WAC TEAM VZW 119
# 15 MAENEN Dani 10138428276 BEL BFY CYCLINGTEAM 132
# 16 RENDERS Luca 10125887186 BEL 4BIKES WESTFIT 147
# 17 ROELS Dima 10105306921 BEL WIELERCLUB "ONDER - ONS PARIKE" VZW 188
# 18 ROELANDT Alessio 10085607029 BEL ACROG-TORMANS 190
# 19 DE BOIS Nand 10073621970 BEL GMS CYCLING TEAM GLABBEEK 215
# 20 DIJKMAN Sven 10087653426 NED DE PEDDELAARS 242
# 21 VAN HOECK Sam 10077885021 BEL WAC TEAM VZW 249
# 22 GEENS Matiz 10065251274 BEL WOUTIM-DEXTERS SPORT 255
# 23 DE LOOSE Senne 10071751890 BEL AVIA-RUDYCO CYCLING TEAM 261
# 24 VANHOUDT Kobe 10065236221 BEL CRABBÉ-DSTNY
# 25 VAN RAEMDONCK Daan 10072115541 BEL AVIA-RUDYCO CYCLING TEAM
# 26 VERVAET Kobe 10130964936 BEL AVIA-RUDYCO CYCLING TEAM
# 27 VAN BELLEGHEM Thibault 10065245820 BEL KON. VC ´T MEETJESLAND - KNESSELARE
# 28 SMET Maurits 10107750109 BEL AVIA-RUDYCO CYCLING TEAM
# 29 VAN VRACEM Robbe 10126379159 BEL ANTWERP CYCLING TEAM KONTICH
# 30 GEENS Lowie 10073065535 BEL WIELERCLUB "ONDER - ONS PARIKE" VZW
# 31 GYSEN Quinten 10120003128 BEL AVIA-RUDYCO CYCLING TEAM
# 32 STEVENS Thibau 10065229652 BEL AVIA-RUDYCO CYCLING TEAM
# 33 PAUWELS Jonas 10065254712 BEL ACROG-TORMANS
# 34 POPPE Flo 10088342429 BEL GOLAZO YOUNG LIONS
# 35 AERTS Torben 10065215407 BEL TEAM KEMPEN CYCLING VZW
# 36 DEROYE Yorbe 10111628186 BEL CRABBÉ-DSTNY
# 37 DE GRAUWE Jairo 10094315912 BEL AVIA-RUDYCO CYCLING TEAM
# 38 VAN DYCK Robbe 10101947889 BEL ANTWERP CYCLING TEAM KONTICH
# 39 WILSSENS Laurens 10065247537 BEL WAC TEAM VZW
# 40 BEELS Finn 10125904869 BEL HOTOND SPORTHOTEL-LITUBRA PARKET-WT WAREGEM
# 41 WAUTELET Grégoire 10147749067 BEL KZLWC - AE
# 42 VERHEUGHE Emilien 10109751743 BEL WIELERCLUB "ONDER - ONS PARIKE" VZW
# 43 TAZELAAR Maike 10023170250 NED ZRTC THEO MIDDELKAMP
# 44 VAN HEMELRIJK Joren 10109587954 BEL WIELERCLUB "ONDER - ONS PARIKE" VZW
# 45 DE NEEF Jens 10158147871 BEL VAN MOER LOGISTICS CYCLING TEAM
# 46 DE CLERCK Miel 10065231268 BEL VAN MOER LOGISTICS CYCLING TEAM
# 47 GROENEVELD Darian 10062936109 NED Individueel
# 48 DEGEZELLE Lars 10119293816 BEL THE LEAD OUT CYCLING ACADEMY
# 49 HAMERLINCK Jasper 10123071661 BEL SPORT EN MOEDIG GENK
# 50 VANDEKERKHOVE Clément 10138322889 FRA ECV BOULZICOURT
# 51 DEGEZELLE Niels 10122623845 BEL THE LEAD OUT CYCLING ACADEMY
# 52 GOOSSENAERTS Sebastiaan 10099362841 BEL ANTWERP CYCLING TEAM KONTICH
# 53 VAN MALDEREN Robbe 10089093268 BEL NOW CYCLING TEAM
# FLANDRIENCROSS-HAMME 16/11/2025
# STARTLIST MEN U23
# Nr Naam UCI ID Nat Club UCI Rank
# Pagina 1 van 4
