# %%
import pandas as pd
import numpy as np
from pathlib import Path
import re

DATA_DIR = Path("data")
CLEAN_DIR = DATA_DIR / "clean"

results_path = CLEAN_DIR / "results_all.csv"
startlists_path = CLEAN_DIR / "startlists_all.csv"

print("Loading:")
print(" -", results_path)
print(" -", startlists_path)

results = pd.read_csv(results_path, parse_dates=["race_date"])
startlists = pd.read_csv(startlists_path, parse_dates=["race_date"])

results.head(), startlists.head()
# Out:
# Loading:
#  - data/clean/results_all.csv
#  - data/clean/startlists_all.csv
# (  Category Name  Place  RacerID First Name     Last Name  \
#  0     Men Elite      1   129684       Toon    Vandebosch
#  1     Men Elite      2   174032     Victor  Van de putte
#  2     Men Elite      3   144667      Niels    Vandeputte
#  3     Men Elite      4   181210       Wout       Janssen
#  4     Men Elite      5   153653    Cameron         Mason
#
#                  Team Name     Time  License  Carried Points  Scored Points  \
#  0         CRELAN-CORENDON  1:04:00      NaN      151.572152     135.875229
#  1  DESCHACHT-HENS CX TEAM  1:04:01      NaN      170.054789     140.548828
#  2                     NaN  1:04:01      NaN      130.398560     145.222426
#  3                     NaN  1:04:02      NaN      181.522616     149.896025
#  4            SEVEN RACING  1:04:02      NaN      157.932693     154.569623
#
#     series_name                   race_name  race_date race_location  \
#  0  Exact Cross  Robotland Cyclocross Essen 2025-10-18    Essen, BEL
#  1  Exact Cross  Robotland Cyclocross Essen 2025-10-18    Essen, BEL
#  2  Exact Cross  Robotland Cyclocross Essen 2025-10-18    Essen, BEL
#  3  Exact Cross  Robotland Cyclocross Essen 2025-10-18    Essen, BEL
#  4  Exact Cross  Robotland Cyclocross Essen 2025-10-18    Essen, BEL
#
#                                               race_id           rider_name
#  0  20251018_exact-cross_robotland-cyclocross-esse...      Toon Vandebosch
#  1  20251018_exact-cross_robotland-cyclocross-esse...  Victor Van de putte
#  2  20251018_exact-cross_robotland-cyclocross-esse...     Niels Vandeputte
#  3  20251018_exact-cross_robotland-cyclocross-esse...         Wout Janssen
#  4  20251018_exact-cross_robotland-cyclocross-esse...        Cameron Mason  ,
#      Nr                    Naam        UCI ID  Nat  \
#  0  1.0              AERTS Toon  1.000759e+10  BEL
#  1  2.0              NYS Thibau  1.006500e+10  BEL
#  2  3.0  VANTHOURENHOUT Michael  1.000716e+10  BEL
#  3  4.0        VANDEPUTTE Niels  1.001633e+10  BEL
#  4  5.0           WYSEURE Joran  1.006492e+10  BEL
#
#                                        Club  UCI Rank  series_name  \
#  0                   DESCHACHT-HENS CX TEAM       2.0          NaN
#  1                      BALOISE GLOWI LIONS       9.0          NaN
#  2  PAUWELS SAUZEN - ALTEZ INDUSTRIEBOUW CT       1.0          NaN
#  3      ALPECIN-DECEUNINCK DEVELOPMENT TEAM       4.0          NaN
#  4                          CRELAN-CORENDON       5.0          NaN
#
#                                             race_name race_date  race_location  \
#  0  Telenet Superprestige AARDBEIENCROSS-MERKSPLAS...       NaT            NaN
#  1  Telenet Superprestige AARDBEIENCROSS-MERKSPLAS...       NaT            NaN
#  2  Telenet Superprestige AARDBEIENCROSS-MERKSPLAS...       NaT            NaN
#  3  Telenet Superprestige AARDBEIENCROSS-MERKSPLAS...       NaT            NaN
#  4  Telenet Superprestige AARDBEIENCROSS-MERKSPLAS...       NaT            NaN
#
#                                               race_id category_full  \
#  0  unknown_standalone_telenet-superprestige-aardb...     Men Elite
#  1  unknown_standalone_telenet-superprestige-aardb...     Men Elite
#  2  unknown_standalone_telenet-superprestige-aardb...     Men Elite
#  3  unknown_standalone_telenet-superprestige-aardb...     Men Elite
#  4  unknown_standalone_telenet-superprestige-aardb...     Men Elite
#
#                 rider_name
#  0              AERTS Toon
#  1              NYS Thibau
#  2  VANTHOURENHOUT Michael
#  3        VANDEPUTTE Niels
#  4           WYSEURE Joran  )

# %%
def normalize_name(s):
    if pd.isna(s):
        return None
    s = str(s).strip().lower()
    # remove accents
    s = (
        s.replace("é", "e").replace("è", "e").replace("ë", "e")
         .replace("ó", "o").replace("ò", "o").replace("ö", "o")
         .replace("á", "a").replace("à", "a").replace("ä", "a")
         .replace("ü", "u")
    )
    # collapse multiple spaces
    s = re.sub(r"\s+", " ", s)
    return s

results["rider_name_norm"] = results["rider_name"].apply(normalize_name)
startlists["rider_name_norm"] = startlists["rider_name"].apply(normalize_name)

# %%
# Ensure string dtype for merge compatibility
startlists["UCI ID"] = startlists["UCI ID"].astype(str)

# %%
results = results.sort_values(["rider_name_norm", "race_date"])

def add_form_features(df):
    df = df.copy()

    # Races so far per rider
    df["races_so_far"] = df.groupby("rider_name_norm").cumcount()

    place_shifted = df.groupby("rider_name_norm")["Place"].shift(1)

    df["avg_place_last3"] = (
        place_shifted.groupby(df["rider_name_norm"])
        .rolling(3).mean().reset_index(level=0, drop=True)
    )

    df["best_place_last5"] = (
        place_shifted.groupby(df["rider_name_norm"])
        .rolling(5).min().reset_index(level=0, drop=True)
    )

    df["last_place"] = place_shifted
    df["days_since_last_race"] = (
        df.groupby("rider_name_norm")["race_date"].diff().dt.days
    )

    df["last_carried_points"] = df.groupby("rider_name_norm")["Carried Points"].shift(1)
    df["last_scored_points"] = df.groupby("rider_name_norm")["Scored Points"].shift(1)

    return df

results_feat = add_form_features(results)
results_feat.head()
# Out:
#      Category Name  Place  RacerID First Name          Last Name  \
# 1440   Women Elite     18   196998      Adèle          Hurteloup
# 306     Men Junior     20   240497       Adne             Cappon
# 1138    Men Junior     44   241251    Adriaan         Van bommel
# 1016  Women Junior     20   229563     Aitana  Gutierrez velarde
# 198    Women Elite     18   202425      Alana           Polfliet
#
#                               Team Name     Time  License  Carried Points  \
# 1440  VELOPRO-EGS GROUP-ALPHAMOTORHOMES  0:54:03      NaN      392.521707
# 306                                 NaN    41:22      NaN      370.000000
# 1138                                NaN  -2 LAPS      NaN      370.000000
# 1016                                NaN  0:41:11      NaN      449.740608
# 198                                 NaN  0:56:06      NaN      505.277027
#
#       Scored Points  ...                                            race_id  \
# 1440     343.504268  ...  20251101_x-o-badkamers-trofee_koppenbergcross_...
# 306      305.302491  ...  20251025_exact-cross_internationale-cyclocross...
# 1138     455.701145  ...  20251102_x-o-badkamers-trofee_rapencross_loker...
# 1016     456.297097  ...  20251109_uec-cyclocross_european-championships...
# 198      393.450092  ...  20251004_exact-cross_berencross_tielt-meulebek...
#
#                     rider_name           rider_name_norm races_so_far  \
# 1440           Adèle Hurteloup           adele hurteloup            0
# 306                Adne Cappon               adne cappon            0
# 1138        Adriaan Van bommel        adriaan van bommel            0
# 1016  Aitana Gutierrez velarde  aitana gutierrez velarde            0
# 198             Alana Polfliet            alana polfliet            0
#
#      avg_place_last3 best_place_last5 last_place  days_since_last_race  \
# 1440             NaN              NaN        NaN                   NaN
# 306              NaN              NaN        NaN                   NaN
# 1138             NaN              NaN        NaN                   NaN
# 1016             NaN              NaN        NaN                   NaN
# 198              NaN              NaN        NaN                   NaN
#
#       last_carried_points  last_scored_points
# 1440                  NaN                 NaN
# 306                   NaN                 NaN
# 1138                  NaN                 NaN
# 1016                  NaN                 NaN
# 198                   NaN                 NaN
#
# [5 rows x 24 columns]

# %%
out_path = CLEAN_DIR / "results_with_features.csv"
results_feat.to_csv(out_path, index=False)
out_path
# Out:
# PosixPath('data/clean/results_with_features.csv')

# %%
feature_cols = [
    "races_so_far",
    "avg_place_last3",
    "best_place_last5",
    "last_place",
    "days_since_last_race",
    "last_carried_points",
    "last_scored_points",
]

train_base = results_feat[
    ["race_id", "rider_name", "rider_name_norm", "Place"] + feature_cols
].copy()

train_base.head()
# Out:
#                                                 race_id  \
# 1440  20251101_x-o-badkamers-trofee_koppenbergcross_...
# 306   20251025_exact-cross_internationale-cyclocross...
# 1138  20251102_x-o-badkamers-trofee_rapencross_loker...
# 1016  20251109_uec-cyclocross_european-championships...
# 198   20251004_exact-cross_berencross_tielt-meulebek...
#
#                     rider_name           rider_name_norm  Place  races_so_far  \
# 1440           Adèle Hurteloup           adele hurteloup     18             0
# 306                Adne Cappon               adne cappon     20             0
# 1138        Adriaan Van bommel        adriaan van bommel     44             0
# 1016  Aitana Gutierrez velarde  aitana gutierrez velarde     20             0
# 198             Alana Polfliet            alana polfliet     18             0
#
#       avg_place_last3  best_place_last5  last_place  days_since_last_race  \
# 1440              NaN               NaN         NaN                   NaN
# 306               NaN               NaN         NaN                   NaN
# 1138              NaN               NaN         NaN                   NaN
# 1016              NaN               NaN         NaN                   NaN
# 198               NaN               NaN         NaN                   NaN
#
#       last_carried_points  last_scored_points
# 1440                  NaN                 NaN
# 306                   NaN                 NaN
# 1138                  NaN                 NaN
# 1016                  NaN                 NaN
# 198                   NaN                 NaN

# %%
train_path = CLEAN_DIR / "train_race_rows.csv"
train_base.to_csv(train_path, index=False)
train_path
# Out:
# PosixPath('data/clean/train_race_rows.csv')

# %%
# Prepare startlists merge keys
startlists["UCI ID"] = startlists["UCI ID"].replace("None", np.nan)
startlists["merge_id"] = startlists["UCI ID"].copy()

# If UCI ID missing → fallback to normalized name
startlists.loc[startlists["merge_id"].isna(), "merge_id"] = (
    "name:" + startlists["rider_name_norm"]
)

# Build the same kind of merge key for results
results_feat["merge_id"] = np.where(
    results_feat.get("UCI ID", pd.Series([None]*len(results_feat))).notna(),
    results_feat.get("UCI ID", None),
    "name:" + results_feat["rider_name_norm"]
)

# Deduplicate on merge_id + race_id on the results side
results_dedup = results_feat.drop_duplicates(subset=["merge_id", "race_id"])

# %%
merged = startlists.merge(
    results_dedup[
        ["merge_id", "race_id"] + feature_cols + ["Place"]
    ],
    on="merge_id",
    how="left",
)

merged.head(20)
# Out:
#       Nr                    Naam         UCI ID  Nat  \
# 0    1.0              AERTS Toon  10007586087.0  BEL
# 1    2.0              NYS Thibau  10065004835.0  BEL
# 2    3.0  VANTHOURENHOUT Michael  10007155651.0  BEL
# 3    4.0        VANDEPUTTE Niels  10016327609.0  BEL
# 4    5.0           WYSEURE Joran  10064921777.0  BEL
# 5    6.0          SWEECK Laurens  10006912646.0  BEL
# 6    7.0       VAN DER HAAR Lars  10006118660.0  NED
# 7    8.0             RONHAAR Pim  10023108212.0  NED
# 8    9.0      ORTS LLORET Felipe  10009004715.0  ESP
# 9   10.0              KUHN Kevin  10009746763.0  SUI
# 10  11.0       NIEUWENHUIS Joris  10008705833.0  NED
# 11  12.0           MASON Cameron  10023574923.0  GBR
# 12  13.0           MICHELS Jente  10065014333.0  BEL
# 13  14.0           HENDRIKX Mees  10016519484.0  NED
# 14  15.0               KAMP Ryan  10023356166.0  NED
# 15  16.0         VANDEBOSCH Toon  10010943604.0  BEL
# 16  17.0            CORSUS Yordi  10065119518.0  BEL
# 17  18.0        DE BRUYCKERE Kay  10065053638.0  BEL
# 18  19.0  SUAREZ FERNANDEZ Kevin  10007584572.0  ESP
# 19  20.0     VAN DE PUTTE Victor  10064985940.0  BEL
#
#                                        Club  UCI Rank  series_name  \
# 0                    DESCHACHT-HENS CX TEAM       2.0          NaN
# 1                       BALOISE GLOWI LIONS       9.0          NaN
# 2   PAUWELS SAUZEN - ALTEZ INDUSTRIEBOUW CT       1.0          NaN
# 3       ALPECIN-DECEUNINCK DEVELOPMENT TEAM       4.0          NaN
# 4                           CRELAN-CORENDON       5.0          NaN
# 5                           CRELAN-CORENDON       7.0          NaN
# 6                       BALOISE GLOWI LIONS       8.0          NaN
# 7                       BALOISE GLOWI LIONS      10.0          NaN
# 8                        RIDLEY RACING TEAM      11.0          NaN
# 9                           HEIZOMAT - CUBE      14.0          NaN
# 10                       RIDLEY RACING TEAM      15.0          NaN
# 11                             SEVEN RACING      18.0          NaN
# 12      ALPECIN-DECEUNINCK DEVELOPMENT TEAM      20.0          NaN
# 13                          HEIZOMAT - CUBE      22.0          NaN
# 14      ALPECIN-DECEUNINCK DEVELOPMENT TEAM      24.0          NaN
# 15                          CRELAN-CORENDON      26.0          NaN
# 16  PAUWELS SAUZEN - ALTEZ INDUSTRIEBOUW CT      34.0          NaN
# 17  PAUWELS SAUZEN - ALTEZ INDUSTRIEBOUW CT      35.0          NaN
# 18                      NESTA - MMR CX TEAM      37.0          NaN
# 19                   DESCHACHT-HENS CX TEAM      40.0          NaN
#
#                                             race_name race_date  \
# 0   Telenet Superprestige AARDBEIENCROSS-MERKSPLAS...       NaT
# 1   Telenet Superprestige AARDBEIENCROSS-MERKSPLAS...       NaT
# 2   Telenet Superprestige AARDBEIENCROSS-MERKSPLAS...       NaT
# 3   Telenet Superprestige AARDBEIENCROSS-MERKSPLAS...       NaT
# 4   Telenet Superprestige AARDBEIENCROSS-MERKSPLAS...       NaT
# 5   Telenet Superprestige AARDBEIENCROSS-MERKSPLAS...       NaT
# 6   Telenet Superprestige AARDBEIENCROSS-MERKSPLAS...       NaT
# 7   Telenet Superprestige AARDBEIENCROSS-MERKSPLAS...       NaT
# 8   Telenet Superprestige AARDBEIENCROSS-MERKSPLAS...       NaT
# 9   Telenet Superprestige AARDBEIENCROSS-MERKSPLAS...       NaT
# 10  Telenet Superprestige AARDBEIENCROSS-MERKSPLAS...       NaT
# 11  Telenet Superprestige AARDBEIENCROSS-MERKSPLAS...       NaT
# 12  Telenet Superprestige AARDBEIENCROSS-MERKSPLAS...       NaT
# 13  Telenet Superprestige AARDBEIENCROSS-MERKSPLAS...       NaT
# 14  Telenet Superprestige AARDBEIENCROSS-MERKSPLAS...       NaT
# 15  Telenet Superprestige AARDBEIENCROSS-MERKSPLAS...       NaT
# 16  Telenet Superprestige AARDBEIENCROSS-MERKSPLAS...       NaT
# 17  Telenet Superprestige AARDBEIENCROSS-MERKSPLAS...       NaT
# 18  Telenet Superprestige AARDBEIENCROSS-MERKSPLAS...       NaT
# 19  Telenet Superprestige AARDBEIENCROSS-MERKSPLAS...       NaT
#
#     race_location  ...       merge_id race_id_y races_so_far avg_place_last3  \
# 0             NaN  ...  10007586087.0       NaN          NaN             NaN
# 1             NaN  ...  10065004835.0       NaN          NaN             NaN
# 2             NaN  ...  10007155651.0       NaN          NaN             NaN
# 3             NaN  ...  10016327609.0       NaN          NaN             NaN
# 4             NaN  ...  10064921777.0       NaN          NaN             NaN
# 5             NaN  ...  10006912646.0       NaN          NaN             NaN
# 6             NaN  ...  10006118660.0       NaN          NaN             NaN
# 7             NaN  ...  10023108212.0       NaN          NaN             NaN
# 8             NaN  ...  10009004715.0       NaN          NaN             NaN
# 9             NaN  ...  10009746763.0       NaN          NaN             NaN
# 10            NaN  ...  10008705833.0       NaN          NaN             NaN
# 11            NaN  ...  10023574923.0       NaN          NaN             NaN
# 12            NaN  ...  10065014333.0       NaN          NaN             NaN
# 13            NaN  ...  10016519484.0       NaN          NaN             NaN
# 14            NaN  ...  10023356166.0       NaN          NaN             NaN
# 15            NaN  ...  10010943604.0       NaN          NaN             NaN
# 16            NaN  ...  10065119518.0       NaN          NaN             NaN
# 17            NaN  ...  10065053638.0       NaN          NaN             NaN
# 18            NaN  ...  10007584572.0       NaN          NaN             NaN
# 19            NaN  ...  10064985940.0       NaN          NaN             NaN
#
#    best_place_last5 last_place  days_since_last_race  last_carried_points  \
# 0               NaN        NaN                   NaN                  NaN
# 1               NaN        NaN                   NaN                  NaN
# 2               NaN        NaN                   NaN                  NaN
# 3               NaN        NaN                   NaN                  NaN
# 4               NaN        NaN                   NaN                  NaN
# 5               NaN        NaN                   NaN                  NaN
# 6               NaN        NaN                   NaN                  NaN
# 7               NaN        NaN                   NaN                  NaN
# 8               NaN        NaN                   NaN                  NaN
# 9               NaN        NaN                   NaN                  NaN
# 10              NaN        NaN                   NaN                  NaN
# 11              NaN        NaN                   NaN                  NaN
# 12              NaN        NaN                   NaN                  NaN
# 13              NaN        NaN                   NaN                  NaN
# 14              NaN        NaN                   NaN                  NaN
# 15              NaN        NaN                   NaN                  NaN
# 16              NaN        NaN                   NaN                  NaN
# 17              NaN        NaN                   NaN                  NaN
# 18              NaN        NaN                   NaN                  NaN
# 19              NaN        NaN                   NaN                  NaN
#
#     last_scored_points  Place
# 0                  NaN    NaN
# 1                  NaN    NaN
# 2                  NaN    NaN
# 3                  NaN    NaN
# 4                  NaN    NaN
# 5                  NaN    NaN
# 6                  NaN    NaN
# 7                  NaN    NaN
# 8                  NaN    NaN
# 9                  NaN    NaN
# 10                 NaN    NaN
# 11                 NaN    NaN
# 12                 NaN    NaN
# 13                 NaN    NaN
# 14                 NaN    NaN
# 15                 NaN    NaN
# 16                 NaN    NaN
# 17                 NaN    NaN
# 18                 NaN    NaN
# 19                 NaN    NaN
#
# [20 rows x 24 columns]

# %%
out_path = CLEAN_DIR / "startlists_enriched.csv"
merged.to_csv(out_path, index=False)
out_path
# Out:
# PosixPath('data/clean/startlists_enriched.csv')
